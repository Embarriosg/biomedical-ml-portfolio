# %% [markdown]
# #### Week #02 | Day #08
# # Matplotlib Basics

# %% [markdown]
# ### What is Matplotlib? <br>
#
# Matplotlib is a comprehensive library for creating static, animated, and interactive visualizations in Python.
# [Matplotlib.org](https://matplotlib.org/stable/plot_types/index) <br>
#
# ### Why do we use it?
# We use Matplotlib to:
# - Visualize data and detect patterns or trends
# - Explore datasets during data analysis (EDA)
# - Present results in a clear and interpretable way
# - Support conclusions with visual evidence
# - In machine learning and scientific computing, plots are essential to understand model behavior, data distributions, and performance.
#
# Most of the Matplotlib utilities lies under the pyplot submodule, and are usually imported under the plt alias:

# %%
import matplotlib.pyplot as plt
